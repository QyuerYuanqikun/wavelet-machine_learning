# %%
import os
import cv2
import numpy as np
import random

# %%
def add_gaussian_noise(image):
    """为图像添加高斯噪声"""
    # 获取图像的行数、列数和通道数
    row, col, ch = image.shape
    mean = 0  # 设定高斯噪声的平均值为0
    # 随机生成标准差，例如在0.5到1.5之间
    sigma = random.uniform(0.5, 1.5)
    # 生成和图像大小一样的高斯噪声矩阵
    gauss = np.random.normal(mean, sigma, (row, col, ch))
    # 将噪声矩阵的形状调整为和图像一致，并转换为uint8类型（图像通常是这种类型）
    gauss = gauss.reshape(row, col, ch).astype('uint8')
    # 将噪声添加到原始图像上
    noisy = cv2.add(image, gauss)
    return noisy

# %%
def process_images(input_dir, output_dir):
    """遍历输入目录的所有图像，添加噪声并保存到输出目录"""
    # 检查输出目录是否存在，如果不存在则创建
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # 遍历输入目录下的所有文件
    for filename in os.listdir(input_dir):
        # 检查文件是否为图像文件（基于文件扩展名）
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')):
            # 构建图像的完整路径
            img_path = os.path.join(input_dir, filename)
            # 使用OpenCV读取图像
            image = cv2.imread(img_path)
            # 向读取的图像添加高斯噪声
            noisy_image = add_gaussian_noise(image)
            # 将带有噪声的图像保存到输出目录
            cv2.imwrite(os.path.join(output_dir, filename), noisy_image)
            print(f'Processed and saved {filename}')

# %%
# 定义输入和输出目录
input_dir = 'E:\\wavelet\\Image\\Flickr1024 Dataset\\Test_same_size'
output_dir = 'E:\\wavelet\\Image\\Flickr1024 Dataset\\Test_same_size_Gauss'

# %%
# 处理图像
process_images(input_dir, output_dir)
# Out:
# Processed and saved 001_L.png
# Processed and saved 001_R.png
# Processed and saved 002_L.png
# Processed and saved 002_R.png
# Processed and saved 003_L.png
# Processed and saved 003_R.png
# Processed and saved 004_L.png
# Processed and saved 004_R.png
# Processed and saved 005_L.png
# Processed and saved 005_R.png
# Processed and saved 006_L.png
# Processed and saved 006_R.png
# Processed and saved 007_L.png
# Processed and saved 007_R.png
# Processed and saved 008_L.png
# Processed and saved 008_R.png
# Processed and saved 009_L.png
# Processed and saved 009_R.png
# Processed and saved 010_L.png
# Processed and saved 010_R.png
# Processed and saved 011_L.png
# Processed and saved 011_R.png
# Processed and saved 012_L.png
# Processed and saved 012_R.png
# Processed and saved 013_L.png
# Processed and saved 013_R.png
# Processed and saved 014_L.png
# Processed and saved 014_R.png
# Processed and saved 015_L.png
# Processed and saved 015_R.png
# Processed and saved 016_L.png
# Processed and saved 016_R.png
# Processed and saved 017_L.png
# Processed and saved 017_R.png
# Processed and saved 018_L.png
# Processed and saved 018_R.png
# Processed and saved 019_L.png
# Processed and saved 019_R.png
# Processed and saved 020_L.png
# Processed and saved 020_R.png
# Processed and saved 021_L.png
# Processed and saved 021_R.png
# Processed and saved 022_L.png
# Processed and saved 022_R.png
# Processed and saved 023_L.png
# Processed and saved 023_R.png
# Processed and saved 024_L.png
# Processed and saved 024_R.png
# Processed and saved 025_L.png
# Processed and saved 025_R.png
# Processed and saved 026_L.png
# Processed and saved 026_R.png
# Processed and saved 027_L.png
# Processed and saved 027_R.png
# Processed and saved 028_L.png
# Processed and saved 028_R.png
# Processed and saved 029_L.png
# Processed and saved 029_R.png
# Processed and saved 030_L.png
# Processed and saved 030_R.png
# Processed and saved 031_L.png
# Processed and saved 031_R.png
# Processed and saved 032_L.png
# Processed and saved 032_R.png
# Processed and saved 033_L.png
# Processed and saved 033_R.png
# Processed and saved 034_L.png
# Processed and saved 034_R.png
# Processed and saved 035_L.png
# Processed and saved 035_R.png
# Processed and saved 036_L.png
# Processed and saved 036_R.png
# Processed and saved 037_L.png
# Processed and saved 037_R.png
# Processed and saved 038_L.png
# Processed and saved 038_R.png
# Processed and saved 039_L.png
# Processed and saved 039_R.png
# Processed and saved 040_L.png
# Processed and saved 040_R.png
# Processed and saved 041_L.png
# Processed and saved 041_R.png
# Processed and saved 042_L.png
# Processed and saved 042_R.png
# Processed and saved 043_L.png
# Processed and saved 043_R.png
# Processed and saved 044_L.png
# Processed and saved 044_R.png
# Processed and saved 045_L.png
# Processed and saved 045_R.png
# Processed and saved 046_L.png
# Processed and saved 046_R.png
# Processed and saved 047_L.png
# Processed and saved 047_R.png
# Processed and saved 048_L.png
# Processed and saved 048_R.png
# Processed and saved 049_L.png
# Processed and saved 049_R.png
# Processed and saved 050_L.png
# Processed and saved 050_R.png
# Processed and saved 051_L.png
# Processed and saved 051_R.png
# Processed and saved 052_L.png
# Processed and saved 052_R.png
# Processed and saved 053_L.png
# Processed and saved 053_R.png
# Processed and saved 054_L.png
# Processed and saved 054_R.png
# Processed and saved 055_L.png
# Processed and saved 055_R.png
# Processed and saved 056_L.png
# Processed and saved 056_R.png
# Processed and saved 057_L.png
# Processed and saved 057_R.png
# Processed and saved 058_L.png
# Processed and saved 058_R.png
# Processed and saved 059_L.png
# Processed and saved 059_R.png
# Processed and saved 060_L.png
# Processed and saved 060_R.png
# Processed and saved 061_L.png
# Processed and saved 061_R.png
# Processed and saved 062_L.png
# Processed and saved 062_R.png
# Processed and saved 063_L.png
# Processed and saved 063_R.png
# Processed and saved 064_L.png
# Processed and saved 064_R.png
# Processed and saved 065_L.png
# Processed and saved 065_R.png
# Processed and saved 066_L.png
# Processed and saved 066_R.png
# Processed and saved 067_L.png
# Processed and saved 067_R.png
# Processed and saved 068_L.png
# Processed and saved 068_R.png
# Processed and saved 069_L.png
# Processed and saved 069_R.png
# Processed and saved 070_L.png
# Processed and saved 070_R.png
# Processed and saved 071_L.png
# Processed and saved 071_R.png
# Processed and saved 072_L.png
# Processed and saved 072_R.png
# Processed and saved 073_L.png
# Processed and saved 073_R.png
# Processed and saved 074_L.png
# Processed and saved 074_R.png
# Processed and saved 075_L.png
# Processed and saved 075_R.png
# Processed and saved 076_L.png
# Processed and saved 076_R.png
# Processed and saved 077_L.png
# Processed and saved 077_R.png
# Processed and saved 078_L.png
# Processed and saved 078_R.png
# Processed and saved 079_L.png
# Processed and saved 079_R.png
# Processed and saved 080_L.png
# Processed and saved 080_R.png
# Processed and saved 081_L.png
# Processed and saved 081_R.png
# Processed and saved 082_L.png
# Processed and saved 082_R.png
# Processed and saved 083_L.png
# Processed and saved 083_R.png
# Processed and saved 084_L.png
# Processed and saved 084_R.png
# Processed and saved 085_L.png
# Processed and saved 085_R.png
# Processed and saved 086_L.png
# Processed and saved 086_R.png
# Processed and saved 087_L.png
# Processed and saved 087_R.png
# Processed and saved 088_L.png
# Processed and saved 088_R.png
# Processed and saved 089_L.png
# Processed and saved 089_R.png
# Processed and saved 090_L.png
# Processed and saved 090_R.png
# Processed and saved 091_L.png
# Processed and saved 091_R.png
# Processed and saved 092_L.png
# Processed and saved 092_R.png
# Processed and saved 093_L.png
# Processed and saved 093_R.png
# Processed and saved 094_L.png
# Processed and saved 094_R.png
# Processed and saved 095_L.png
# Processed and saved 095_R.png
# Processed and saved 096_L.png
# Processed and saved 096_R.png
# Processed and saved 097_L.png
# Processed and saved 097_R.png
# Processed and saved 098_L.png
# Processed and saved 098_R.png
# Processed and saved 099_L.png
# Processed and saved 099_R.png
# Processed and saved 100_L.png
# Processed and saved 100_R.png
# Processed and saved 101_L.png
# Processed and saved 101_R.png
# Processed and saved 102_L.png
# Processed and saved 102_R.png
# Processed and saved 103_L.png
# Processed and saved 103_R.png
# Processed and saved 104_L.png
# Processed and saved 104_R.png
# Processed and saved 105_L.png
# Processed and saved 105_R.png
# Processed and saved 106_L.png
# Processed and saved 106_R.png
# Processed and saved 107_L.png
# Processed and saved 107_R.png
# Processed and saved 108_L.png
# Processed and saved 108_R.png
# Processed and saved 109_L.png
# Processed and saved 109_R.png
# Processed and saved 110_L.png
# Processed and saved 110_R.png
# Processed and saved 111_L.png
# Processed and saved 111_R.png
# Processed and saved 112_L.png
# Processed and saved 112_R.png
